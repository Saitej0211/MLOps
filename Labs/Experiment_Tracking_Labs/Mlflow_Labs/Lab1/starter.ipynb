# %%
# !pip3 install mlflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: mlflow in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (2.16.2)
# Requirement already satisfied: gunicorn<24 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from mlflow) (23.0.0)
# Requirement already satisfied: docker<8,>=4.0.0 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from mlflow) (7.1.0)
# Requirement already satisfied: graphene<4 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from mlflow) (3.3)
# Requirement already satisfied: markdown<4,>=3.3 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from mlflow) (3.7)
# Requirement already satisfied: pandas<3 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from mlflow) (2.2.2)
# Requirement already satisfied: Jinja2<4,>=2.11 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from mlflow) (3.1.4)
# Requirement already satisfied: numpy<3 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from mlflow) (2.0.2)
# Requirement already satisfied: scipy<2 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from mlflow) (1.13.1)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from mlflow) (2.0.35)
# Requirement already satisfied: matplotlib<4 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from mlflow) (3.9.2)
# Requirement already satisfied: Flask<4 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from mlflow) (3.0.3)
# Requirement already satisfied: pyarrow<18,>=4.0.0 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from mlflow) (17.0.0)
# Requirement already satisfied: alembic!=1.10.0,<2 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from mlflow) (1.13.2)
# Requirement already satisfied: scikit-learn<2 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from mlflow) (1.5.2)
# Requirement already satisfied: mlflow-skinny==2.16.2 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from mlflow) (2.16.2)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from mlflow-skinny==2.16.2->mlflow) (3.1.43)
# Requirement already satisfied: protobuf<6,>=3.12.0 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from mlflow-skinny==2.16.2->mlflow) (5.28.1)
# Requirement already satisfied: cachetools<6,>=5.0.0 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from mlflow-skinny==2.16.2->mlflow) (5.5.0)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from mlflow-skinny==2.16.2->mlflow) (0.32.2)
# Requirement already satisfied: click<9,>=7.0 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from mlflow-skinny==2.16.2->mlflow) (8.1.7)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from mlflow-skinny==2.16.2->mlflow) (1.27.0)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from mlflow-skinny==2.16.2->mlflow) (0.5.1)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from mlflow-skinny==2.16.2->mlflow) (1.27.0)
# Requirement already satisfied: importlib-metadata!=4.7.0,<9,>=3.7.0 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from mlflow-skinny==2.16.2->mlflow) (8.4.0)
# Requirement already satisfied: pyyaml<7,>=5.1 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from mlflow-skinny==2.16.2->mlflow) (6.0.2)
# Requirement already satisfied: packaging<25 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from mlflow-skinny==2.16.2->mlflow) (24.1)
# Requirement already satisfied: cloudpickle<4 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from mlflow-skinny==2.16.2->mlflow) (3.0.0)
# Requirement already satisfied: requests<3,>=2.17.3 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from mlflow-skinny==2.16.2->mlflow) (2.32.3)
# Requirement already satisfied: typing-extensions>=4 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from alembic!=1.10.0,<2->mlflow) (4.12.2)
# Requirement already satisfied: Mako in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.5)
# Requirement already satisfied: google-auth~=2.0 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==2.16.2->mlflow) (2.34.0)
# Requirement already satisfied: urllib3>=1.26.0 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from docker<8,>=4.0.0->mlflow) (2.2.3)
# Requirement already satisfied: itsdangerous>=2.1.2 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: blinker>=1.6.2 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from Flask<4->mlflow) (1.8.2)
# Requirement already satisfied: Werkzeug>=3.0.0 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from Flask<4->mlflow) (3.0.4)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==2.16.2->mlflow) (4.0.11)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==2.16.2->mlflow) (5.0.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.16.2->mlflow) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.16.2->mlflow) (4.9)
# Requirement already satisfied: aniso8601<10,>=8 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from graphene<4->mlflow) (9.0.1)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from graphene<4->mlflow) (3.2.4)
# Requirement already satisfied: zipp>=0.5 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from importlib-metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==2.16.2->mlflow) (3.20.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from Jinja2<4,>=2.11->mlflow) (2.1.5)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from matplotlib<4->mlflow) (4.53.1)
# Requirement already satisfied: pillow>=8 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from matplotlib<4->mlflow) (10.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from matplotlib<4->mlflow) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from matplotlib<4->mlflow) (1.3.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from matplotlib<4->mlflow) (6.4.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from matplotlib<4->mlflow) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from matplotlib<4->mlflow) (3.1.4)
# Requirement already satisfied: cycler>=0.10 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: deprecated>=1.2.6 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.16.2->mlflow) (1.2.14)
# Requirement already satisfied: wrapt<2,>=1.10 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from deprecated>=1.2.6->opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.16.2->mlflow) (1.16.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.48b0 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.16.2->mlflow) (0.48b0)
# Requirement already satisfied: pytz>=2020.1 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from pandas<3->mlflow) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from pandas<3->mlflow) (2024.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.16.2->mlflow) (0.6.1)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib<4->mlflow) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.16.2->mlflow) (2024.8.30)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.16.2->mlflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.16.2->mlflow) (3.10)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from scikit-learn<2->mlflow) (3.5.0)
# Requirement already satisfied: joblib>=1.2.0 in /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages (from scikit-learn<2->mlflow) (1.4.2)
# WARNING: You are using pip version 21.2.4; however, version 24.2 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import mlflow

from sklearn.model_selection import train_test_split
from sklearn.datasets import load_diabetes
from sklearn.ensemble import RandomForestRegressor

mlflow.autolog()

db = load_diabetes()
X_train, X_test, y_train, y_test = train_test_split(db.data, db.target)

# Create and train models.
rf = RandomForestRegressor(n_estimators=100, max_depth=6, max_features=3)
rf.fit(X_train, y_train)

# Use the model to make predictions on the test dataset.
predictions = rf.predict(X_test)
# Out:
# /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# 2024/09/18 19:52:33 WARNING mlflow.utils.autologging_utils: MLflow sklearn autologging is known to be compatible with 0.24.1 <= scikit-learn <= 1.5.1, but the installed version is 1.5.2. If you encounter errors during autologging, try upgrading / downgrading scikit-learn to a compatible version, or try upgrading MLflow.
# 2024/09/18 19:52:34 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.
# 2024/09/18 19:52:34 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'aea3f24ad1834226b16b805004ff5f10', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow

# %%
# !mlflow ui --port=5001
# Out:
# /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# [2024-09-18 19:52:38 -0400] [3463] [INFO] Starting gunicorn 23.0.0
# [2024-09-18 19:52:38 -0400] [3463] [INFO] Listening at: http://127.0.0.1:5001 (3463)
# [2024-09-18 19:52:38 -0400] [3463] [INFO] Using worker: sync
# [2024-09-18 19:52:38 -0400] [3464] [INFO] Booting worker with pid: 3464
# [2024-09-18 19:52:38 -0400] [3465] [INFO] Booting worker with pid: 3465
# [2024-09-18 19:52:38 -0400] [3466] [INFO] Booting worker with pid: 3466
# /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# [2024-09-18 19:52:38 -0400] [3467] [INFO] Booting worker with pid: 3467
# /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
import mlflow 
from sklearn.model_selection import train_test_split 
from sklearn.datasets import load_diabetes

# set the experiment id
mlflow.set_experiment(experiment_id="0")

mlflow.autolog() 
db = load_diabetes() 

X_train, X_test, y_train, y_test = train_test_split(db.data, db.target) 

# Create and train models. 
rf = RandomForestRegressor(n_estimators=100, max_depth=6, max_features=3) 
rf.fit(X_train, y_train) 

# Use the model to make predictions on the test dataset. 
predictions = rf.predict(X_test)
# Out:
# 2024/09/18 02:01:32 WARNING mlflow.utils.autologging_utils: MLflow sklearn autologging is known to be compatible with 0.24.1 <= scikit-learn <= 1.5.1, but the installed version is 1.5.2. If you encounter errors during autologging, try upgrading / downgrading scikit-learn to a compatible version, or try upgrading MLflow.
# 2024/09/18 02:01:32 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.
# 2024/09/18 02:01:32 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'dc2be698ba244d5cbc8282190cb709d2', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow

# %%
# !mlflow ui --port=5001
# Out:
# /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# [2024-09-18 02:01:56 -0400] [42479] [INFO] Starting gunicorn 23.0.0
# [2024-09-18 02:01:56 -0400] [42479] [INFO] Listening at: http://127.0.0.1:5001 (42479)
# [2024-09-18 02:01:56 -0400] [42479] [INFO] Using worker: sync
# [2024-09-18 02:01:56 -0400] [42480] [INFO] Booting worker with pid: 42480
# /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# [2024-09-18 02:01:56 -0400] [42481] [INFO] Booting worker with pid: 42481
# [2024-09-18 02:01:56 -0400] [42482] [INFO] Booting worker with pid: 42482
# /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# [2024-09-18 02:01:56 -0400] [42483] [INFO] Booting worker with pid: 42483
# /Users/saitejareddygajula/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# ^C
# [2024-09-18 02:07:25 -0400] [42479] [INFO] Handling signal: int
# [2024-09-18 02:07:25 -0400] [42483] [INFO] Worker exiting (pid: 42483)
# [2024-09-18 02:07:25 -0400] [42480] [INFO] Worker exiting (pid: 42480)
# [2024-09-18 02:07:25 -0400] [42481] [INFO] Worker exiting (pid: 42481)
# [2024-09-18 02:07:25 -0400] [42482] [INFO] Worker exiting (pid: 42482)

# %% [markdown]
# ### Store ML models

# %%
import mlflow
from mlflow.models import infer_signature

from sklearn.model_selection import train_test_split
from sklearn.datasets import load_diabetes
from sklearn.ensemble import RandomForestRegressor

with mlflow.start_run() as run:
    # Load the diabetes dataset.
    db = load_diabetes()
    X_train, X_test, y_train, y_test = train_test_split(db.data, db.target)

    # Create and train models.
    rf = RandomForestRegressor(n_estimators=100, max_depth=6, max_features=3)
    rf.fit(X_train, y_train)

    # Use the model to make predictions on the test dataset.
    predictions = rf.predict(X_test)
    print(predictions)

    signature = infer_signature(X_test, predictions)
    mlflow.sklearn.log_model(rf, "model", signature=signature)

    print(f"Run ID: {run.info.run_id}")
# Out:
# [191.65805293 110.08384323 195.34955449 234.6304106  144.04968211
#  144.09415445  98.60861823 129.36126763 235.79137322 236.79655764
#  160.02935175 142.00754355 221.73079862 185.99250781 198.12039774
#  144.07537194  93.6229619  197.11257583 210.72273599 125.05198045
#  129.69720168 225.33193233 233.15698867 174.64819594 182.55216076
#  159.09429557  82.03728917 242.82027408 225.69592612 150.09359953
#  109.90696912 185.66582836 206.78258813 125.00367005 223.21842974
#  183.91197894 101.92162984 101.59272477 103.10395872 206.78889862
#  157.73311265 165.49086041 205.55449115 114.0212655  106.8662373
#   90.92231821 189.14720023  90.20383117 133.42285521 240.99125772
#  189.02248016 200.8011729  202.17017035 232.88493089 197.0979561
#  152.09485523 163.2911468  167.59856322 174.49412257  98.78269801
#  112.31968278  83.87301323 144.71953835  97.80908183  79.42914086
#  180.01357625  95.10983942 121.31224558  82.34926097 170.46198966
#  148.56901289  97.4382692  106.09051948 102.47718328 153.43164662
#  136.47145148 165.11861866 215.41192865 146.11607549 118.01235803
#  202.79354706 169.52425167 174.36178156 109.43650877 189.32404193
#   89.38575322  98.17256432 124.89664979 173.32571101 151.79720346
#  215.55299638 193.71636406 170.30629217  78.74931839 239.87482092
#   82.30354454  94.5974781   92.41972217 162.2244815   91.32225851
#  112.02125417 177.54291127 108.51234237 152.27221408 128.51256214
#  160.3642438  187.04970594  80.55982002 100.31270526 161.43865069
#  164.53739804]
# Run ID: cc1f16c095a9450e91148ed946d80335

# %%
# !mlflow ui --port=5001
# Out:
# [2023-09-27 20:38:23 -0400] [342146] [INFO] Starting gunicorn 21.2.0
# [2023-09-27 20:38:23 -0400] [342146] [INFO] Listening at: http://127.0.0.1:5001 (342146)
# [2023-09-27 20:38:23 -0400] [342146] [INFO] Using worker: sync
# [2023-09-27 20:38:23 -0400] [342147] [INFO] Booting worker with pid: 342147
# [2023-09-27 20:38:23 -0400] [342148] [INFO] Booting worker with pid: 342148
# [2023-09-27 20:38:23 -0400] [342149] [INFO] Booting worker with pid: 342149
# [2023-09-27 20:38:23 -0400] [342150] [INFO] Booting worker with pid: 342150
# ^C
# [2023-09-27 20:49:11 -0400] [342146] [INFO] Handling signal: int
# [2023-09-27 20:49:11 -0400] [342150] [INFO] Worker exiting (pid: 342150)
# [2023-09-27 20:49:11 -0400] [342148] [INFO] Worker exiting (pid: 342148)
# [2023-09-27 20:49:11 -0400] [342149] [INFO] Worker exiting (pid: 342149)
# [2023-09-27 20:49:11 -0400] [342147] [INFO] Worker exiting (pid: 342147)

# %% [markdown]
# ### Load a model

# %%
import mlflow

from sklearn.model_selection import train_test_split
from sklearn.datasets import load_diabetes

db = load_diabetes()
X_train, X_test, y_train, y_test = train_test_split(db.data, db.target)

model = mlflow.sklearn.load_model("mlruns/0/a7edd2653458481ab60488297d06a781/artifacts/model/")
predictions = model.predict(X_test)
print(predictions)
# Out:
# [122.40261887 234.18467364 140.18766533 243.91707622 245.53061941
#  187.89789308  96.28890875  88.89452932 135.70200448 107.04530356
#  103.76999767 176.28014701 180.4834001   76.14683975 128.55257159
#  185.09300542 143.69013658 150.82986054  97.45081585 112.9968235
#  138.76118    116.49273203 101.60445853  87.30251689 122.56539834
#   89.62155793 226.26600831 210.18484846 106.98860284 259.98304437
#  260.79224118 109.14294108 211.76111755 135.42689954 120.7820993
#   93.86100571 218.16837761 248.54687141  95.94761874 123.11095363
#   90.80937315 106.67951664 260.53131605 274.26832419 173.32572024
#  176.62147535 146.23732091 139.90918216  98.94524125 156.17888733
#  215.7182531  195.07027538 141.03099423 155.00970735 103.6021406
#  237.3877715   78.4928254  231.54420999 192.39051206 188.42045515
#  103.50332736 190.70644941 107.2176039  158.99833758 186.97634425
#   95.74975624 177.2550257  111.68677597  91.86114235 110.04041889
#  212.80348334 167.24063782 226.23657994 269.06005143 196.84296301
#  167.20063281 211.95597729 212.12435339  95.01096582  97.37922156
#  182.88081136  86.21616879 247.50600837 123.0995639  113.96160832
#  254.25881866  97.76847376 115.044682   190.71255852 190.55107463
#  239.8945894  119.53352494 206.77145734  83.69078723 103.80851766
#  173.31096402  93.11702409 272.98167626 237.48078917 265.62473364
#  167.78437991 124.61651218 224.36413898 132.96030478 152.0436169
#  115.71766056 173.60923352 158.97365094  96.75704568 178.15232774
#  178.31689982]
